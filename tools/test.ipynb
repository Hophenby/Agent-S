# %%
import pyautogui

pyautogui.click(1213, 216, clicks=2, interval=0.2, duration=0.1, button='left')
pyautogui.click(1213, 216, clicks=1, interval=0.2, duration=0.3, button='left')
pyautogui.click(1213, 216, clicks=1, interval=0.2, duration=0.6, button='left')
